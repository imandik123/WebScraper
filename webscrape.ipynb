# %%
import pandas as pd
from parsel import Selector 
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService

opts =Options()

chrome_path = "/Users/imandikarunaratne/Downloads/chromedriver_mac64/chromedriver"
service = ChromeService(executable_path=chrome_path)

driver = webdriver.Chrome(service=service, options=opts)
# driver = webdriver.Chrome(options=opts, executable_path =chrome_path)


def validate_fields(field):
    if field: 
        passs
        
    else:
        field = 'No results'
        
driver.get('https://www.linkedin.com')
username = driver.find_elements(By.ID,'session_key')
username.send_keys('YOUR EMAIL')
sleep(0.5)
password=driver.find_elements(By.ID,'session_password')
password.send_keys('YOUR PASSWORD')

sign_in_button = driver.find_element(By.XPATH, '//*[@type="submit"]')
sign_in_button.click()
sleep(15)


Jobdata = []
lnks = []

for x in range(0,20,10):
    driver.get(f'https://www.google.com/search?q=site:linkedin.com/in/+AND+%22Python+Developer%22+AND+%22Delhi%22&rlz=1C1CHZO_enIN1023&ei=jPaIY-mEGM6cseMPyZaNmAo&s')
    time.sleep(random.uniform(2.5,4.9))
    linkedin_urls = [my_elem.get_attribute("href") for my_elem in WebDriverWait(driver,20).until(EC.visibility_of_all_elements_located(By.XPATH,"//div[@class='yuRUbf']"))]
    lnks.append(linkedin_urls)

for x in lnks:
    for i in x:
        driver.get(i)
        time.sleep(random.uniform(2.5,4.9))
        sel=Selector(text=driver.page_source)
        name=sel.xpath('//*[starts-with(@class,"text-heading-xlarge inline t-24 v-align-middle break-words")]/text()').extract_first()
        
        if name:
            name=name.strip()
            
        job_title = sel.xpath('//*[starts-with(@class,"text-body-medium break-words")]/text()').extract_first() 
        
        if job_title:
            job_title = job_title.strip()
            
        try:
            company= driver.find_element(By.XPATH, '//ul[@class="pv-text-details_right-panel"]').text
        
        except:
            company='None'
        
        if comapny:
            company = company.strip()
            
        location= sel.xpath('//*[starts-with(@class,"text-body-small inline t-black--light break-words")]/text()').extract_first()
        
        if location:
            location=location.strip()
            
        name=validate_field(name)
        job_title=validate_field(job_title)
        company=validate_field(company)
        location=validate_field(location)
        
        print('\n')
        print('Name: ' + name)
        print('Job Title: ' + job_title)
        print('Company: '+ company)
        print('Location: ' + location)
        print('URL: ', linkedin_url)
        print('\n')
        
        data = { 
            'Name' : name,
            'Job_Title' : job_title,
            'Company': company,
            'Location' : location,
            'URL' : linkedin_url
            
        }
        jobdata.appeand(data)
        
df=pd.Dataframe(Jobdata)
df.to_excel('Jobdata_linkedin.xlsx')
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[4], line 17
#      14 chrome_path = "/Users/imandikarunaratne/Downloads/chromedriver_mac64/chromedriver"
#      15 service = ChromeService(executable_path=chrome_path)
# ---> 17 driver = webdriver.Chrome(service=service, options=opts)
#      18 # driver = webdriver.Chrome(options=opts, executable_path =chrome_path)
#      21 def validate_fields(field):
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
# ...

# %%
print(Jobdata)
